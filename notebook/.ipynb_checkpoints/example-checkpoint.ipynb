# %%
print('hello')
# Out:
# hello

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\prash\\Downloads\\vscode_test\\notebook'

# %%
Root_DIR= os.getcwd()
CONFIG_DIR="config"
CONFIG_FILE_NAME="config.yaml"
CONFIG_FILE_PATH=os.path.join(Root_DIR,CONFIG_DIR,CONFIG_FILE_NAME)

# %%
CONFIG_FILE_PATH
# Out:
# 'C:\\Users\\prash\\Downloads\\vscode_test\\notebook\\config\\config.yaml'

# %%
os.getcwd()
# Out:
# 'c:\\Users\\prash\\Downloads\\vscode_test\\notebook'

# %%
os.chdir('c:\\Users\\prash\\Downloads\\vscode_test')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\prash\\Downloads\\vscode_test'

# %%
from house.util.util import read_yaml_file
from house.constant import *
# Out:
# c:\Users\prash\Downloads\vscode_test

# %%
file=read_yaml_file(CONFIG_FILE_PATH)

# %%
file[TRAINING_PIPELINE_CONFIG_KEY]
# Out:
# {'pipeline_name': 'housing', 'artifact_dir': 'artifact'}

# %%
file[TRAINING_PIPELINE_CONFIG_KEY][TRAINING_PIPELINE_NAME_KEY]
# Out:
# 'housing'

# %%
os.getcwd()
# Out:
# 'c:\\Users\\prash\\Downloads\\vscode_test'

# %%
os.chdir(r'C:\Users\prash\Downloads\vscode_test')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\prash\\Downloads\\vscode_test'

# %%
from house.config.configuration import Configuration
from house.constant import *

# %%
test1=Configuration()

# %%
test1.get_training_pipeline_config()

# %%
DATA_INGESTION_CONFIG_KEY
# Out:
# 'data_ingestion_config'

# %%
config_info=read_yaml_file(CONFIG_FILE_PATH)

# %%
config_info[TRAINING_PIPELINE_CONFIG_KEY]
# Out:
# {'pipeline_name': 'housing', 'artifact_dir': 'artifact'}

# %%
Data_ingestion_info=config_info[DATA_INGESTION_CONFIG_KEY]

# %%
Data_ingestion_info[DATA_INGESTION_DOWNLOAD_URL_KEY]
# Out:
# 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz'

# %%
Data_ingestion_info # type: ignore
# Out:
# {'dataset_download_url': 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz',
#  'raw_data_dir': 'raw_data',
#  'tgz_download_dir': 'tgz_data',
#  'ingested_dir': 'ingested_data',
#  'ingested_train_dir': 'train',
#  'ingested_test_dir': 'test'}

# %%
Data_ingestion_info # type: ignore
# Out:
# {'dataset_download_url': 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz',
#  'raw_data_dir': 'raw_data',
#  'tgz_download_dir': 'tgz_data',
#  'ingested_dir': 'ingested_data',
#  'ingested_train_dir': 'train',
#  'ingested_test_dir': 'test'}

# %%
from house.pipeline.pipeline import Pipeline
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 from house.pipeline.pipeline import Pipeline
#
# File c:\Users\prash\Downloads\vscode_test\house\pipeline\pipeline.py:7
#       5 from house.entity.artifact_entity import DataIngestionArtifact
#       6 from house.entity.config_entity import DataIngestionConfig
# ----> 7 from house.component.data_ingestion import DataIngestion
#       9 import os,sys
#      11 class Pipeline:
#
# File c:\Users\prash\Downloads\vscode_test\house\component\data_ingestion.py:15
#      11 import numpy as np
#      13 from sklearn.model_selection import StratifiedShuffleSplit # type: ignore
# ---> 15 class DataIngestion:
#      16     def __init__(self,data_ingestion_config = DataIngestionConfig()):
#      17         try:
#
# File c:\Users\prash\Downloads\vscode_test\house\component\data_ingestion.py:16, in DataIngestion()
# ...

# %%
pip install -U scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      --------------------------------------- 60.6/60.6 kB 97.7 kB/s eta 0:00:00
# ...

# %%
from house.component.data_ingestion import DataIngestion
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 from house.component.data_ingestion import DataIngestion
#
# File c:\Users\prash\Downloads\vscode_test\house\component\data_ingestion.py:15
#      11 import numpy as np
#      13 from sklearn.model_selection import StratifiedShuffleSplit # type: ignore
# ---> 15 class DataIngestion:
#      16     def __init__(self,data_ingestion_config = DataIngestionConfig()):
#      17         try:
#
# File c:\Users\prash\Downloads\vscode_test\house\component\data_ingestion.py:16, in DataIngestion()
#      15 class DataIngestion:
# ---> 16     def __init__(self,data_ingestion_config = DataIngestionConfig()):
#      17         try:
#      18             logging.info(f"{'='*20}Data Ingestion log started.{'='*20}")
#
# ...

# %%
from house.config.configuration import Configuration

# %%
X=Configuration()

# %%
X.get_data_ingestion_config()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\prash\Downloads\vscode_test\house\config\configuration.py:26, in Configuration.get_data_ingestion_config(self)
#      24 try:
# ---> 26     artifact_dir=self.training_pipeline_config.artifact_dir
#      27     data_ingestion_artifact_dir=os.path.join(artifact_dir,DATA_INGESTION_ARTIFACT_DIR,self.time_stamp)
#
# AttributeError: 'NoneType' object has no attribute 'artifact_dir'
#
# The above exception was the direct cause of the following exception:
#
# HouseException                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 X.get_data_ingestion_config()
#
# File c:\Users\prash\Downloads\vscode_test\house\config\configuration.py:56, in Configuration.get_data_ingestion_config(self)
#      54     logging.info(f"Data ingestion config: {data_ingestion_config}")
# ...

# %%
X.get_training_pipeline_config()

# %%
X.artifact_dir
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 X.artifact_dir
#
# AttributeError: 'Configuration' object has no attribute 'artifact_dir'
